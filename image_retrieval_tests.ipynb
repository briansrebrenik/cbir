# %%
from orb import *

# %%
ref_path = os.getcwd() + '/referenceImages'
query_path = os.getcwd() + '/queryImages'

# %%
#list of file names in reference image folder
ref_images = os.listdir(ref_path)

# %%
#creating descriptors for reference images
ref_desc = create_descriptors(ref_images)
# Out:
# 100%|██████████| 758/758 [01:54<00:00,  6.62it/s]

# %%
query_images = []
#creating list of query image locations
for x in os.listdir(query_path)[1:
                               ]:
    query_images.append(query_path + '/' + x)

# %%
print(f'Number of query images: {len(query_images)}')
# Out:
# Number of query images: 11

# %% [markdown]
# ### Running Image Retrieval Tests on Query Images

# %%
#unable to find match, rotated image
image_retrieval(query_images[0], ref_desc=ref_desc)
# Out:
# Query Image:
# Closest Match:
# jean-fillioux-tres-vieux-[size].png

# %%
#correct on 2nd highest match
image_retrieval(query_images[1], ref_desc=ref_desc, match_num=1)
# Out:
# Query Image:
# Closest Match:
# bache-gabrielsen-american-oak-2.jpeg

# %%
#correct on first match
image_retrieval(query_images[2], ref_desc=ref_desc)
# Out:
# Query Image:
# Closest Match:
# Barrell Bourbon Batch 016-750ml.png

# %%
#correct on first match
image_retrieval(query_images[3], ref_desc=ref_desc)
# Out:
# Query Image:
# Closest Match:
# Ad-Laws-bottled-in-bond.png

# %%
#correct on first match
image_retrieval(query_images[4], ref_desc=ref_desc)
# Out:
# Query Image:
# Closest Match:
# Barrell Bourbon Batch 016-750ml.png

# %%
#correct on first match
image_retrieval(query_images[5], ref_desc=ref_desc)
# Out:
# Query Image:
# Closest Match:
# bache-gabrielsen-american-oak-cognac-[size].png

# %%
#correct on first match
image_retrieval(query_images[6], ref_desc=ref_desc, match_num=0)
# Out:
# Query Image:
# Closest Match:
# dalmore-12-3.jpeg

# %%
#correct on first match
image_retrieval(query_images[7], ref_desc=ref_desc)
# Out:
# Query Image:
# Closest Match:
# Ad-Laws-bottled-in-bond.png

# %%
#correct on first match
image_retrieval(query_images[8], ref_desc=ref_desc)
# Out:
# Query Image:
# Closest Match:
# bache-gabrielsen-american-oak-cognac-[size].png

# %%
#blurry image, unable to find match
image_retrieval(query_images[9], ref_desc=ref_desc)
# Out:
# Query Image:
# Closest Match:
# sagamore-rye-double-oak-[size].png

# %%
#correct on first match
image_retrieval(query_images[10], ref_desc=ref_desc)
# Out:
# Query Image:
# Closest Match:
# Ad-Laws-bottled-in-bond.png

# %% [markdown]
# ### Drawing lines between top 30 matches on images

# %%
image_1 = query_path + '/0.jpg'
image_2 = ref_path + '/Ad-Laws-bottled-in-bond.png'
draw_matches(image_1, image_2, 30)

# %%
image_1 = query_path + '/10.jpg'
image_2 = ref_path + '/Barrell Bourbon Batch 016-750ml.png'
draw_matches(image_1, image_2, 30)
